# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("Data.csv")
# Out:
# C:\Users\mukes\AppData\Local\Temp\ipykernel_6528\1816482340.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv("Data.csv")

# %%
data1=data[["iyear","region_txt","country_txt","city"]]
data1.head()
# Out:
#    iyear                   region_txt         country_txt           city
# 0   1970  Central America & Caribbean  Dominican Republic  Santo Domingo
# 1   1970                North America              Mexico    Mexico city
# 2   1970               Southeast Asia         Philippines        Unknown
# 3   1970               Western Europe              Greece         Athens
# 4   1970                    East Asia               Japan        Fukouka

# %%
data1.isnull().sum()
# Out:
# iyear            0
# region_txt       0
# country_txt      0
# city           434
# dtype: int64

# %%
data1=data1.dropna()

# %%
data1.isnull().sum()
# Out:
# iyear          0
# region_txt     0
# country_txt    0
# city           0
# dtype: int64

# %%
print("HotZone Country:-",data1['country_txt'].value_counts().idxmax())
# Out:
# HotZone Country:- Iraq

# %%
Year=data1.iyear
region=data1.region_txt
pd.crosstab(Year,data1['country_txt']).plot(kind='area',figsize=(15,6))
plt.title('Terrorist Activities in Years')
plt.ylabel('Number of Attacks')
plt.show()
